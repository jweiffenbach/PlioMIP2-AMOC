# %%
## imports
import sys
import os
import numpy as np
import xarray as xr
import cmocean
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib import gridspec
import cartopy
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import eofs
from eofs.xarray import Eof
import cftime
import nc_time_axis

import mtspec

# from pylab import *

import datetime
import time
import glob, os
import math
import matplotlib.colors as colors

# %%
experiment = 'E280' 
model = 'EC-Earth3-LR'
folder = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'

# %% [markdown]
# ## Potential temperature

# %%
experiment = 'E280' 

year1 = 2320
ds = xr.open_dataset(folder+experiment+'/Thetao/thetao_Omon_EC-Earth3-LR_piControl_r1i1p1f1_gn_232001-232012.nc',decode_times=False)
thetao = ds.thetao.mean(dim='time')
thetao = thetao.assign_coords(time=int(year1))
thetao = thetao.expand_dims('time')
for i in range(1,100):
    ds1 = xr.open_dataset(folder+experiment+'/Thetao/thetao_Omon_EC-Earth3-LR_piControl_r1i1p1f1_gn_'+str(year1+i)+'01-'+str(year1+i)+'12.nc',decode_times=False)
    thetao1 = ds1.thetao.mean(dim='time')
    thetao1 = thetao1.assign_coords(time=int(year1+i))
    thetao1 = thetao1.expand_dims('time')
    thetao = xr.merge([thetao, thetao1])

thetaoE280 = thetao    
xr.Dataset.to_netcdf(thetaoE280, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/thetao_annual_100yr.nc')

thetaoE280_100yr = thetaoE280.mean(dim='time')
xr.Dataset.to_netcdf(thetaoE280_100yr, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/thetao_100yr.nc')
# Out:
# <xarray.Dataset>
# Dimensions:    (i: 362, j: 292, lev: 75, time: 100)
# Coordinates:
#   * time       (time) int64 2320 2321 2322 2323 2324 ... 2416 2417 2418 2419
#   * lev        (lev) float64 0.5058 1.556 2.668 ... 5.698e+03 5.902e+03
#   * j          (j) int32 1 2 3 4 5 6 7 8 9 ... 285 286 287 288 289 290 291 292
#   * i          (i) int32 1 2 3 4 5 6 7 8 9 ... 355 356 357 358 359 360 361 362
#     latitude   (j, i) float64 -78.39 -78.39 -78.39 -78.39 ... 50.23 50.01 50.01
#     longitude  (j, i) float64 72.5 73.5 74.5 75.5 ... 73.05 73.04 73.0 72.99
# Data variables:
#     thetao     (time, lev, j, i) float32 nan nan nan nan nan ... nan nan nan nan

# %%
experiment = 'Eoi400' 

year1 = 3307

ds = xr.open_dataset(folder+experiment+'/Thetao/thetao_Omon_EC-Earth3-LR_midPliocene-eoi400_r1i1p1f1_gn_330701-330712.nc',decode_times=False)
thetao = ds.thetao.mean(dim='time')
thetao = thetao.assign_coords(time=int(year1))
thetao = thetao.expand_dims('time')
for i in range(1,100):
    ds1 = xr.open_dataset(folder+experiment+'/Thetao/thetao_Omon_EC-Earth3-LR_midPliocene-eoi400_r1i1p1f1_gn_'+str(year1+i)+'01-'+str(year1+i)+'12.nc',decode_times=False)
    thetao1 = ds1.thetao.mean(dim='time')
    thetao1 = thetao1.assign_coords(time=int(year1+i))
    thetao1 = thetao1.expand_dims('time')
    thetao = xr.merge([thetao, thetao1])

thetaoEoi400 = thetao
xr.Dataset.to_netcdf(thetaoEoi400, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/thetao_annual_100yr.nc')

thetaoEoi400_100yr = thetaoEoi400.mean(dim='time')
xr.Dataset.to_netcdf(thetaoEoi400_100yr, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/thetao_100yr.nc')

# %% [markdown]
# ## Meridional velocity

# %%
experiment = 'E280' 
year1 = 2320
ds = xr.open_dataset(folder+experiment+'/Vo/vo_Omon_EC-Earth3-LR_piControl_r1i1p1f1_gn_232001-232012.nc',decode_times=False)
vo = ds.vo.mean(dim='time')
vo = vo.assign_coords(time=int(year1))
vo = vo.expand_dims('time')
for i in range(1,100):
    ds1 = xr.open_dataset(folder+experiment+'/Vo/vo_Omon_EC-Earth3-LR_piControl_r1i1p1f1_gn_'+str(year1+i)+'01-'+str(year1+i)+'12.nc',decode_times=False)
    vo1 = ds1.vo.mean(dim='time')
    vo1 = vo1.assign_coords(time=int(year1+i))
    vo1 = vo1.expand_dims('time')
    vo = xr.merge([vo, vo1])

voE280 = vo    
xr.Dataset.to_netcdf(voE280, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/vo_annual_100yr.nc')

voE280_100yr = voE280.mean(dim='time')
xr.Dataset.to_netcdf(voE280_100yr, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/vo_100yr.nc')

# %%
experiment = 'Eoi400' 

year1 = 3307

ds = xr.open_dataset(folder+experiment+'/Vo/vo_Omon_EC-Earth3-LR_midPliocene-eoi400_r1i1p1f1_gn_330701-330712.nc',decode_times=False)
vo = ds.vo.mean(dim='time')
vo = vo.assign_coords(time=int(year1))
vo = vo.expand_dims('time')
for i in range(1,100):
    ds1 = xr.open_dataset(folder+experiment+'/Vo/vo_Omon_EC-Earth3-LR_midPliocene-eoi400_r1i1p1f1_gn_'+str(year1+i)+'01-'+str(year1+i)+'12.nc',decode_times=False)
    vo1 = ds1.vo.mean(dim='time')
    vo1 = vo1.assign_coords(time=int(year1+i))
    vo1 = vo1.expand_dims('time')
    vo = xr.merge([vo, vo1])

voEoi400 = vo
xr.Dataset.to_netcdf(voEoi400, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/vo_annual_100yr.nc')

voEoi400_100yr = voEoi400.mean(dim='time')
xr.Dataset.to_netcdf(voEoi400_100yr, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/vo_100yr.nc')

# %% [markdown]
# ## Atlantic MSF

# %%
experiment = 'E280' 

year1 = 2320
ds = xr.open_dataset(folder+experiment+'/AMOC/msftyz_Omon_EC-Earth3-LR_piControl_r1i1p1f1_gn_232001-232012.nc',decode_times=False)
amoc = ds.msftyz[:,1,:,:].mean(dim='time')
amoc = amoc.assign_coords(time=int(year1))
amoc = amoc.expand_dims('time')

for i in range(1,100):
    ds1 = xr.open_dataset(folder+experiment+'/AMOC/msftyz_Omon_EC-Earth3-LR_piControl_r1i1p1f1_gn_'+str(year1+i)+'01-'+str(year1+i)+'12.nc',decode_times=False)
    amoc1 = ds1.msftyz[:,1,:,:].mean(dim='time')
    amoc1 = amoc1.assign_coords(time=int(year1+i))
    amoc1 = amoc1.expand_dims('time')
    amoc = xr.merge([amoc, amoc1])

amocE280 = amoc
xr.Dataset.to_netcdf(amocE280, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/amoc_annual_100yr.nc')

amocE280_100yr = amocE280.mean(dim='time')
xr.Dataset.to_netcdf(amocE280_100yr, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/amoc_100yr.nc')

# %%
experiment = 'Eoi400' 

year1 = 3307
ds = xr.open_dataset(folder+experiment+'/AMOC/msftyz_Omon_EC-Earth3-LR_midPliocene-eoi400_r1i1p1f1_gn_330701-330712.nc',decode_times=False)
amoc = ds.msftyz[:,1,:,:].mean(dim='time')
amoc = amoc.assign_coords(time=int(year1))
amoc = amoc.expand_dims('time')

for i in range(1,100):
    ds1 = xr.open_dataset(folder+experiment+'/AMOC/msftyz_Omon_EC-Earth3-LR_midPliocene-eoi400_r1i1p1f1_gn_'+str(year1+i)+'01-'+str(year1+i)+'12.nc',decode_times=False)
    amoc1 = ds1.msftyz[:,1,:,:].mean(dim='time')
    amoc1 = amoc1.assign_coords(time=int(year1+i))
    amoc1 = amoc1.expand_dims('time')
    amoc = xr.merge([amoc, amoc1])

amocEoi400 = amoc
xr.Dataset.to_netcdf(amocEoi400, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/amoc_annual_100yr.nc')

amocEoi400_100yr = amocEoi400.mean(dim='time')
xr.Dataset.to_netcdf(amocEoi400_100yr, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/amoc_100yr.nc')

# %% [markdown]
# ## Atlantic OHT

# %%
experiment = 'E280' 

year1 = 2320

#Total OHT
ds = xr.open_dataset(folder+experiment+'/OHT/Total/hfbasin_Omon_EC-Earth3-LR_piControl_r1i1p1f1_gn_232001-232012.nc',decode_times=False)
oht = ds.hfbasin[:,1,:].mean(dim='time')
oht = oht.assign_coords(time=int(year1))
oht = oht.expand_dims('time')

for i in range(1,100):
    ds1 = xr.open_dataset(folder+experiment+'/OHT/Total/hfbasin_Omon_EC-Earth3-LR_piControl_r1i1p1f1_gn_'+str(year1+i)+'01-'+str(year1+i)+'12.nc',decode_times=False)
    oht1 = ds1.hfbasin[:,1,:].mean(dim='time')
    oht1 = oht1.assign_coords(time=int(year1+i))
    oht1 = oht1.expand_dims('time')
    oht = xr.merge([oht, oht1])

ohtE280 = oht
xr.Dataset.to_netcdf(ohtE280, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/hfbasin_annual_100yr.nc')

ohtE280_100yr = ohtE280.mean(dim='time')
xr.Dataset.to_netcdf(ohtE280_100yr, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/hfbasin_100yr.nc')

# %%
experiment = 'Eoi400' 

year1 = 3307

#Total OHT
ds = xr.open_dataset(folder+experiment+'/OHT/hfbasin_Omon_EC-Earth3-LR_midPliocene-eoi400_r1i1p1f1_gn_330701-330712.nc',decode_times=False)
oht = ds.hfbasin[:,1,:].mean(dim='time')
oht = oht.assign_coords(time=int(year1))
oht = oht.expand_dims('time')

for i in range(1,100):
    ds1 = xr.open_dataset(folder+experiment+'/OHT/hfbasin_Omon_EC-Earth3-LR_midPliocene-eoi400_r1i1p1f1_gn_'+str(year1+i)+'01-'+str(year1+i)+'12.nc',decode_times=False)
    oht1 = ds1.hfbasin[:,1,:].mean(dim='time')
    oht1 = oht1.assign_coords(time=int(year1+i))
    oht1 = oht1.expand_dims('time')
    oht = xr.merge([oht, oht1])

ohtEoi400 = oht
xr.Dataset.to_netcdf(ohtEoi400, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/hfbasin_annual_100yr.nc')

ohtEoi400_100yr = ohtEoi400.mean(dim='time')
xr.Dataset.to_netcdf(ohtEoi400_100yr, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/hfbasin_100yr.nc')

# %% [markdown]
# ## Salinity

# %%
# Salinity
model = 'EC-Earth3-LR'
experiment = 'E280' 
folder = '/Volumes/External/Salinity/'+model+'/'+experiment+'/'
filename_data= 'so*.nc'
files = glob.glob(folder+filename_data)
files.sort()

year1 = 2320
ds = xr.open_dataset(files[0], decode_times=False)

so = ds.so.mean(dim='time')
so = so.assign_coords(time=int(year1))
so = so.expand_dims('time')

for i in range(1,100):
    ds1 = xr.open_dataset(files[i], decode_times=False)
    so1 = ds1.so.mean(dim='time')
    so1 = so1.assign_coords(time=int(year1+i))
    so1 = so1.expand_dims('time')
    so = xr.merge([so, so1])

soE280 = so    
xr.Dataset.to_netcdf(soE280, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/so_annual_100yr.nc')

soE280_100yr = soE280.mean(dim='time')
xr.Dataset.to_netcdf(soE280_100yr, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/so_100yr.nc')

# %%
model = 'EC-Earth3-LR'
experiment = 'Eoi400' 
folder = '/Volumes/External/Salinity/'+model+'/'+experiment+'/'
filename_data= 'so*.nc'
files = glob.glob(folder+filename_data)
files.sort()

year1 = 3307
ds = xr.open_dataset(files[0], decode_times=False)

so = ds.so.mean(dim='time')
so = so.assign_coords(time=int(year1))
so = so.expand_dims('time')

for i in range(1,100):
    ds1 = xr.open_dataset(files[i], decode_times=False)
    so1 = ds1.so.mean(dim='time')
    so1 = so1.assign_coords(time=int(year1+i))
    so1 = so1.expand_dims('time')
    so = xr.merge([so, so1])

soEoi400 = so
xr.Dataset.to_netcdf(soEoi400, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/so_annual_100yr.nc')

soEoi400_100yr = soEoi400.mean(dim='time')
xr.Dataset.to_netcdf(soEoi400_100yr, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/so_100yr.nc')

# %% [markdown]
# ## Sea ice

# %%
# Salinity
model = 'EC-Earth3.3'
experiment = 'Eoi400' 
folder = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/EC-Earth3.3'+'/'+experiment+'/SI/'
filename_data= 'siconc*.nc'
files = glob.glob(folder+filename_data)
files.sort()

ds1 = xr.open_mfdataset(files, concat_dim='time',combine='nested', decode_times=False)
ds1['time'] = np.arange(1,1201)
xr.Dataset.to_netcdf(ds1, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/si_monthly.nc')
