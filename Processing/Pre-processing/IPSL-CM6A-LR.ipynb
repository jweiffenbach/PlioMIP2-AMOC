# %%
## imports
import sys
import os
import numpy as np
import xarray as xr
import cmocean
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib import gridspec
import cartopy
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import eofs
from eofs.xarray import Eof
import cftime
import nc_time_axis

import mtspec

# from pylab import *

import datetime
import time
import glob, os
import math
import matplotlib.colors as colors

# %%
experiment = 'Eoi400' 
model = 'IPSL-CM6A-LR'
folder = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'

# %% [markdown]
# ## Potential temperature

# %%
experiment = 'Eoi400' 

if experiment == 'Eoi400':
    ds = xr.open_dataset('/Users/6497241/Desktop/IPSLlargefile/thetao_Omon_IPSL-CM6A-LR_midPliocene-eoi400_r1i1p1f1_gn_195001-204912.nc',decode_times=False)
else:
    ds = xr.open_dataset('/Users/6497241/Desktop/IPSLlargefile/thetao_Omon_IPSL-CM6A-LR_piControl_r1i1p1f1_gn_375001-384912.nc',decode_times=False)

import timeit

start_time = timeit.default_timer()
thetao1 = ds.thetao[0:120].mean(dim='time')
thetao1 = thetao1.assign_coords(year=int(1))
thetao1 = thetao1.expand_dims('year')
print(1)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
thetao2 = ds.thetao[120:240].mean(dim='time')
thetao2 = thetao2.assign_coords(year=int(2))
thetao2 = thetao2.expand_dims('year')
print(2)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
thetao3 = ds.thetao[240:360].mean(dim='time')
thetao3 = thetao3.assign_coords(year=int(3))
thetao3 = thetao3.expand_dims('year')
print(3)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
thetao4 = ds.thetao[360:480].mean(dim='time')
thetao4 = thetao4.assign_coords(year=int(4))
thetao4 = thetao4.expand_dims('year')
print(4)
print(timeit.default_timer() - start_time)

thetao5 = ds.thetao[480:600].mean(dim='time')
thetao5 = thetao5.assign_coords(year=int(5))
thetao5 = thetao5.expand_dims('year')
print(5)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
thetao6 = ds.thetao[600:720].mean(dim='time')
thetao6 = thetao6.assign_coords(year=int(6))
thetao6 = thetao6.expand_dims('year')
print(6)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
thetao7 = ds.thetao[720:840].mean(dim='time')
thetao7 = thetao7.assign_coords(year=int(7))
thetao7 = thetao7.expand_dims('year')
print(7)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
thetao8 = ds.thetao[840:960].mean(dim='time')
thetao8 = thetao8.assign_coords(year=int(8))
thetao8 = thetao8.expand_dims('year')
print(8)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
thetao9 = ds.thetao[960:1080].mean(dim='time')
thetao9 = thetao9.assign_coords(year=int(9))
thetao9 = thetao9.expand_dims('year')
print(9)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
thetao10 = ds.thetao[1080:1200].mean(dim='time')
thetao10 = thetao10.assign_coords(year=int(10))
thetao10 = thetao10.expand_dims('year')
print(10)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
thetao = xr.merge([thetao1, thetao2, thetao3, thetao4, thetao5, thetao6, thetao7, thetao8, thetao9, thetao10])
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
thetao = thetao.mean(dim='year')
print(timeit.default_timer() - start_time)

xr.Dataset.to_netcdf(thetao, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/thetao_100yr.nc')
# Out:
# 5
# 293.50539648000085
# 6
# 99.77084478600045
# 7
# 95.58000493399959
# 8
# 95.09285984800044
# 9
# 99.17669723200015
# 10
# 96.28793203299938
# 13.773049069999615
# 0.6212420410010964

# %% [markdown]
# ## Velocity

# %%
experiment = 'E280' 

if experiment == 'Eoi400':
    ds = xr.open_dataset('/Users/6497241/Desktop/IPSLlargefile/vo_Omon_IPSL-CM6A-LR_midPliocene-eoi400_r1i1p1f1_gn_195001-204912.nc',decode_times=False)
else:
    ds = xr.open_dataset('/Users/6497241/Desktop/IPSLlargefile/vo_Omon_IPSL-CM6A-LR_piControl_r1i1p1f1_gn_375001-384912.nc',decode_times=False)

import timeit

start_time = timeit.default_timer()
vo1 = ds.vo[0:120].mean(dim='time')
vo1 = vo1.assign_coords(year=int(1))
vo1 = vo1.expand_dims('year')
print(1)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
vo2 = ds.vo[120:240].mean(dim='time')
vo2 = vo2.assign_coords(year=int(2))
vo2 = vo2.expand_dims('year')
print(2)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
vo3 = ds.vo[240:360].mean(dim='time')
vo3 = vo3.assign_coords(year=int(3))
vo3 = vo3.expand_dims('year')
print(3)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
vo4 = ds.vo[360:480].mean(dim='time')
vo4 = vo4.assign_coords(year=int(4))
vo4 = vo4.expand_dims('year')
print(4)
print(timeit.default_timer() - start_time)

vo5 = ds.vo[480:600].mean(dim='time')
vo5 = vo5.assign_coords(year=int(5))
vo5 = vo5.expand_dims('year')
print(5)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
vo6 = ds.vo[600:720].mean(dim='time')
vo6 = vo6.assign_coords(year=int(6))
vo6 = vo6.expand_dims('year')
print(6)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
vo7 = ds.vo[720:840].mean(dim='time')
vo7 = vo7.assign_coords(year=int(7))
vo7 = vo7.expand_dims('year')
print(7)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
vo8 = ds.vo[840:960].mean(dim='time')
vo8 = vo8.assign_coords(year=int(8))
vo8 = vo8.expand_dims('year')
print(8)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
vo9 = ds.vo[960:1080].mean(dim='time')
vo9 = vo9.assign_coords(year=int(9))
vo9 = vo9.expand_dims('year')
print(9)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
vo10 = ds.vo[1080:1200].mean(dim='time')
vo10 = vo10.assign_coords(year=int(10))
vo10 = vo10.expand_dims('year')
print(10)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
vo = xr.merge([vo1, vo2, vo3, vo4, vo5, vo6, vo7, vo8, vo9, vo10])
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
vo = vo.mean(dim='year')
print(timeit.default_timer() - start_time)

xr.Dataset.to_netcdf(vo, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/vo_100yr.nc')
# Out:
# 1
# 106.05751079500078
# 2
# 134.76388698700066
# 3
# 115.73159558600128
# 4
# 103.36192017999929
# 5
# 203.9575277290005
# 6
# 96.47473491900018
# 7
# 104.77189656399969
# 8
# 103.87897243999942
# 9
# 107.42832800999895
# 10
# 110.98583114699977
# 16.989778034001574
# 0.7291234979984438

# %% [markdown]
# ## Salinity

# %%
experiment = 'E280' 

if experiment == 'Eoi400':
    ds = xr.open_dataset('/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/IPSL-CM6A-LR/'+experiment+'/so_Omon_IPSL-CM6A-LR_midPliocene-eoi400_r1i1p1f1_gn_195001-204912.nc',decode_times=False)
else:
    ds = xr.open_dataset('/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/IPSL-CM6A-LR/'+experiment+'/so_Omon_IPSL-CM6A-LR_piControl_r1i1p1f1_gn_375001-384912.nc',decode_times=False)

import timeit

start_time = timeit.default_timer()
so1 = ds.so[0:120].mean(dim='time')
so1 = so1.assign_coords(year=int(1))
so1 = so1.expand_dims('year')
print(1)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
so2 = ds.so[120:240].mean(dim='time')
so2 = so2.assign_coords(year=int(2))
so2 = so2.expand_dims('year')
print(2)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
so3 = ds.so[240:360].mean(dim='time')
so3 = so3.assign_coords(year=int(3))
so3 = so3.expand_dims('year')
print(3)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
so4 = ds.so[360:480].mean(dim='time')
so4 = so4.assign_coords(year=int(4))
so4 = so4.expand_dims('year')
print(4)
print(timeit.default_timer() - start_time)

so5 = ds.so[480:600].mean(dim='time')
so5 = so5.assign_coords(year=int(5))
so5 = so5.expand_dims('year')
print(5)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
so6 = ds.so[600:720].mean(dim='time')
so6 = so6.assign_coords(year=int(6))
so6 = so6.expand_dims('year')
print(6)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
so7 = ds.so[720:840].mean(dim='time')
so7 = so7.assign_coords(year=int(7))
so7 = so7.expand_dims('year')
print(7)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
so8 = ds.so[840:960].mean(dim='time')
so8 = so8.assign_coords(year=int(8))
so8 = so8.expand_dims('year')
print(8)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
so9 = ds.so[960:1080].mean(dim='time')
so9 = so9.assign_coords(year=int(9))
so9 = so9.expand_dims('year')
print(9)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
so10 = ds.so[1080:1200].mean(dim='time')
so10 = so10.assign_coords(year=int(10))
so10 = so10.expand_dims('year')
print(10)
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
so = xr.merge([so1, so2, so3, so4, so5, so6, so7, so8, so9, so10])
print(timeit.default_timer() - start_time)

start_time = timeit.default_timer()
so = so.mean(dim='year')
print(timeit.default_timer() - start_time)

xr.Dataset.to_netcdf(so, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/so_100yr.nc')
# Out:
# 1
# 100.69006205000005
# 2
# 93.51140879400009
# 3
# 91.63900171599971
# 4
# 92.55198152899993
# 5
# 188.81496714000014
# 6
# 90.53012182800012
# 7
# 92.0183331029998
# 8
# 88.95230411200009
# 9
# 99.91542648800032
# 10
# 100.22633696100002
# 13.89935535099994
# 0.6074799809998694

# %%
## AMOC

# %%
experiment = 'E280'
ds = xr.open_dataset(folder+experiment+'/msftyz_Omon_IPSL-CM6A-LR_piControl_r1i1p1f1_gn_355001-384912.nc',decode_times=False)
amoc = ds.msftyz[2400:3600,1,:,:,0]

year1 = 2750

amoc1 = amoc[0:12].mean(dim='time')
amoc1 = amoc1.assign_coords(year=int(year1))
amoc1 = amoc1.expand_dims('year')

for i in range(1,100):
    amoc2 = amoc[int(i*12):int((i+1)*12)].mean(dim='time')
    amoc2 = amoc2.assign_coords(year=int(year1+i))
    amoc2 = amoc2.expand_dims('year')
    amoc1 = xr.merge([amoc1, amoc2])

amocE280 = amoc1
xr.Dataset.to_netcdf(amocE280, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/amoc_annual_100yr.nc')

amocE280_100yr = amocE280.mean(dim='year')
xr.Dataset.to_netcdf(amocE280_100yr, path = '/Users/6497241/surfdrive/Documents/PlioMIP2-OHT/Data/Raw_data/'+model+'/'+experiment+'/amoc_100yr.nc')
