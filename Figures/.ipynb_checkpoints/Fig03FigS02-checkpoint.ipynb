# %%
## imports
import sys
import os
import numpy as np
import xarray as xr
import cmocean
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib import gridspec
import cartopy
import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import eofs
from eofs.xarray import Eof
import cftime
import nc_time_axis
import cmocean as cmo
import mtspec

# from pylab import *

import datetime
import time
import glob, os
import math
import matplotlib.colors as colors
from mpl_toolkits.axes_grid1 import make_axes_locatable
import xskillscore
from defs import trim_axs, amocstrength, corsst, pvalmask, lon180, detrend_dim, corsst_10rm
from cartopy.mpl.ticker import (LongitudeFormatter, LatitudeFormatter,
                                LatitudeLocator)
import cartopy.mpl.ticker as cticker
import matplotlib.ticker as mticker

# %%
folder = '/Volumes/External/DataPlioMIP2/Data/Processed/'
modellist =   ['GISS2.1G', 'EC-Earth3-LR', 'CCSM4-UoT', 'CCSM4-Utr','CCSM4', 'CESM1.2', 'CESM2','IPSL-CM6A','MIROC4m','COSMOS', 'HadCM3', 'NorESM1-F','HadGEM3']

# %% [markdown]
# ## Figure 03: SST correlation maps

# %%
#Open one SST field to initialize field
model = modellist[0]
ds = xr.open_dataset(folder+model+'/E280/'+'SST_annual_100yr.nc')

#Initialize fields for correlation and pvalue
dsE280 = xr.Dataset(data_vars = dict(corr=(["model","lat", "lon"], np.zeros([len(modellist), len(ds.lat), len(ds.lon)]))), coords = dict(model = modellist,  lat = ds.lat.values, lon = ds.lon.values))
dsE280['pval'] = dsE280.corr.copy(deep=True)

dsEoi400 = dsE280.copy(deep=True)

#Compute correlation and p-value for every model and experiment
for i in range(len(modellist)):
    dsE280.corr[i,:,:], dsE280.pval[i,:,:] = corsst(modellist[i], 'E280')
    dsEoi400.corr[i, :,:], dsEoi400.pval[i,:,:] = corsst(modellist[i], 'Eoi400')

#Rewrite coordinates from -180 to 180 
dsE280 = lon180(dsE280)
dsEoi400 = lon180(dsEoi400)

# %%
#Construct 2D arrays of longitude and latitude to produce scatter plots for significance
lon = dsE280.lon
lat = dsE280.lat

coords = xr.Dataset(data_vars = dict(lat2D=(["lat", "lon"], np.repeat(lat.values[:, np.newaxis], len(lon), axis=1))), coords = dict(lat = lat.values, lon = lon.values))
coords['lon2D'] = coords.lat2D.copy(deep=True)
coords.lon2D[:] = np.transpose(np.repeat(lon.values[:, np.newaxis], len(lat), axis=1))

# %%
plt.rcParams['xtick.labelsize']=13
plt.rcParams['ytick.labelsize']=13
plt.rcParams['axes.labelsize'] = 13

fig = plt.figure(figsize=(15, 24), dpi=300)
outer = gridspec.GridSpec(4, 4, wspace=0.1, hspace=0.2)

mask = pvalmask(dsE280,0.05)
mask2 = pvalmask(dsEoi400,0.05)

for i in range(len(modellist)):
    inner = gridspec.GridSpecFromSubplotSpec(2, 1,
                    subplot_spec=outer[i], wspace=0.1, hspace=0.15)
    model = modellist[i]
    for j in range(2):
        ax = plt.subplot(inner[j], projection = ccrs.Miller())
        if j == 0:
            im = ax.pcolormesh(dsE280.lon, dsE280.lat, dsE280.corr[i].fillna(-1000), transform = ccrs.PlateCarree(), cmap='cmo.balance', shading='auto',vmin = -0.7, vmax = 0.7)
            cs = ax.scatter(coords.lon2D.where(mask[i]>0)[::4,::4], coords.lat2D.where(mask[i]>0)[::4,::4], transform = ccrs.PlateCarree(), s=2, facecolors='none', edgecolors='black', linewidth=0.5)
            cp1 = ax.contour(dsE280.lon, dsE280.lat, dsE280.corr[i], levels=[0.4, 1e24], colors='w', zorder =1, alpha=0.8,transform = ccrs.PlateCarree())
            ax.set_title(model, fontsize=14)
            ax.set_title('PI', fontsize=14, loc='right')
            ax.tick_params(labelbottom=False)   
        elif j==1:
            im = ax.pcolormesh(dsEoi400.lon, dsEoi400.lat, dsEoi400.corr[i].fillna(-1000), transform = ccrs.PlateCarree(), cmap='cmo.balance', shading='auto',vmin = -0.7, vmax = 0.7)
            cs = ax.scatter(coords.lon2D.where(mask2[i]>0)[::4,::4], coords.lat2D.where(mask2[i]>0)[::4,::4], transform = ccrs.PlateCarree(), s=2, facecolors='none', edgecolors='black', linewidth=0.5)
            cp1 = ax.contour(dsEoi400.lon, dsEoi400.lat, dsEoi400.corr[i], levels=[0.4, 1e24], colors='w', alpha=0.8,transform = ccrs.PlateCarree())
            ax.set_title('mPWP', fontsize=14, loc='right')
            #ax.set_xlabel('Longitude')
        if i!=0 and i!=4 and i!=8 and i !=12:
            ax.tick_params(labelleft=False)
            
        ax.set_extent([-90, 30, 20, 85], ccrs.PlateCarree())
        ax.clabel(cp1, inline=True, inline_spacing=0.1, fmt = '%.1f',  fontsize=10)
        
        ax.set_xticks(np.arange(-90,31,30), crs=ccrs.PlateCarree())
        lon_formatter = cticker.LongitudeFormatter()
        ax.xaxis.set_major_formatter(lon_formatter)

        ax.set_yticks(np.arange(30,80,15), crs=ccrs.PlateCarree())
        lat_formatter = cticker.LatitudeFormatter()
        ax.yaxis.set_major_formatter(lat_formatter)
        
        fig.add_subplot(ax)

fig.subplots_adjust(bottom=0.15, top=0.9, left=0.1, right=0.9)
    # Add a colorbar axis at the bottom of the graph
cbar_ax = fig.add_axes([0.3, 0.11, 0.4, 0.01])
    # Draw the colorbar
cbar=fig.colorbar(im, cax=cbar_ax,orientation='horizontal', label='Correlation (R)', pad=0.01)
plt.savefig('fig03.png', bbox_inches='tight')
# Out:
# /opt/anaconda3/envs/myenv/lib/python3.8/site-packages/cartopy/crs.py:228: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   if len(multi_line_string) > 1:
# /opt/anaconda3/envs/myenv/lib/python3.8/site-packages/cartopy/crs.py:239: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# /opt/anaconda3/envs/myenv/lib/python3.8/site-packages/cartopy/crs.py:239: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   line_strings = list(multi_line_string)
# ...

# %% [markdown]
# ## Compute area of positive correlation, mean positive correlation and maximum correlation for all models

# %%
#Create 30-60N North Atlantic mask
import regionmask

Atlantic = np.array([[-80,30],[-72,70],[-40,70],[-40,80], [20,80],[10,50],[-5,40], [-5,30]])
region = regionmask.Regions([Atlantic])

ax = region.plot()
ax.set_extent([0, 350, 0, 90], crs=ccrs.PlateCarree())

# define lat/ lon grid
ds = xr.open_dataset(folder+model+'/Eoi400/'+'SST_annual_100yr.nc')
ds = lon180(ds)

maskA = region.mask(ds.lon.values, ds.lat.values)
# Out:
# /opt/anaconda3/envs/myenv/lib/python3.8/site-packages/regionmask/core/plot.py:12: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   coords += [np.asarray(p.exterior)[:, :2]] + [

# %%
#Count the number of positive significant grid cells in North Atlantic
mask = pvalmask(dsE280,0.05)
mask2 = pvalmask(dsEoi400, 0.05)

a = dsE280.corr.where(mask>0).where(maskA>-1).where(dsE280.corr>0)
b = dsEoi400.corr.where(mask2>0).where(maskA>-1).where(dsEoi400.corr>0)

pcountE280 = a.count(dim=['lon','lat'])
pcountEoi400 = b.count(dim=['lon','lat'])

#Compute total number of grid cells in North Atlantic
totalE280 = dsE280.corr.where(maskA>-1).count(dim=['lon','lat'])
totalEoi400 = dsE280.corr.where(maskA>-1).count(dim=['lon','lat'])

perE280 = pcountE280/totalE280*100
perEoi400 = pcountEoi400/totalEoi400*100

print(modellist)
print(perE280)
print(perEoi400)
# Out:
# ['GISS2.1G', 'EC-Earth3-LR', 'CCSM4-UoT', 'CCSM4-Utr', 'CCSM4', 'CESM1.2', 'CESM2', 'IPSL-CM6A', 'MIROC4m', 'COSMOS', 'HadCM3', 'NorESM1-F', 'HadGEM3']
# <xarray.DataArray 'corr' (model: 13)>
# array([20.99927589,  0.47479912, 28.13406381,  9.51351351, 18.52252252,
#        14.12612613, 33.94594595, 29.45428262,  5.44312631,  6.86086623,
#        14.80416816, 15.05082095, 18.82905674])
# Coordinates:
#   * model    (model) <U12 'GISS2.1G' 'EC-Earth3-LR' ... 'NorESM1-F' 'HadGEM3'
# <xarray.DataArray 'corr' (model: 13)>
# array([54.16364953, 51.05916728, 26.36158556, 44.43243243, 16.64864865,
#        20.57657658,  0.        , 21.57571377, 24.7034194 , 48.06439249,
#        33.92022997, 10.51602815, 11.42031081])
# Coordinates:
#   * model    (model) <U12 'GISS2.1G' 'EC-Earth3-LR' ... 'NorESM1-F' 'HadGEM3'

# %%
#Compute weights for mean
weights = np.cos(np.deg2rad(ds.lat))
weights.name = "weights"

meanE280 = a.weighted(weights).mean(dim=['lon','lat'])
meanEoi400 = b.weighted(weights).mean(dim=['lon','lat'])

print(modellist)
print(meanE280)
print(meanEoi400)
# Out:
# ['GISS2.1G', 'EC-Earth3-LR', 'CCSM4-UoT', 'CCSM4-Utr', 'CCSM4', 'CESM1.2', 'CESM2', 'IPSL-CM6A', 'MIROC4m', 'COSMOS', 'HadCM3', 'NorESM1-F', 'HadGEM3']
# <xarray.DataArray 'corr' (model: 13)>
# array([0.39447681, 0.28369682, 0.34685116, 0.29393396, 0.31111404,
#        0.32275098, 0.36306725, 0.36594341, 0.30466015, 0.2792011 ,
#        0.31373273, 0.28292868, 0.27855319])
# Coordinates:
#   * model    (model) <U12 'GISS2.1G' 'EC-Earth3-LR' ... 'NorESM1-F' 'HadGEM3'
# <xarray.DataArray 'corr' (model: 13)>
# array([0.39962413, 0.34640343, 0.38213104, 0.4263177 , 0.29702371,
#        0.32097597,        nan, 0.36141266, 0.33216276, 0.41531292,
#        0.40608308, 0.31751267, 0.29614497])
# Coordinates:
#   * model    (model) <U12 'GISS2.1G' 'EC-Earth3-LR' ... 'NorESM1-F' 'HadGEM3'

# %%
maxE280 = a.max(dim=['lon','lat'])
maxEoi400 = b.max(dim=['lon','lat'])

print(modellist)
print(maxE280)
print(maxEoi400)
# Out:
# ['GISS2.1G', 'EC-Earth3-LR', 'CCSM4-UoT', 'CCSM4-Utr', 'CCSM4', 'CESM1.2', 'CESM2', 'IPSL-CM6A', 'MIROC4m', 'COSMOS', 'HadCM3', 'NorESM1-F', 'HadGEM3']
# <xarray.DataArray 'corr' (model: 13)>
# array([0.69135788, 0.36487549, 0.53849123, 0.39733436, 0.46039911,
#        0.50108314, 0.55466867, 0.54498557, 0.47098031, 0.37604921,
#        0.49182329, 0.37167912, 0.359411  ])
# Coordinates:
#   * model    (model) <U12 'GISS2.1G' 'EC-Earth3-LR' ... 'NorESM1-F' 'HadGEM3'
# <xarray.DataArray 'corr' (model: 13)>
# array([0.60029037, 0.54051508, 0.62169224, 0.72094765, 0.42591465,
#        0.47901002,        nan, 0.56389474, 0.55422226, 0.65364142,
#        0.60968716, 0.45354762, 0.50110977])
# Coordinates:
#   * model    (model) <U12 'GISS2.1G' 'EC-Earth3-LR' ... 'NorESM1-F' 'HadGEM3'

# %%
#Multi-model mean (excluding HadGEM3):
print(np.mean(perE280[:-1]))
print(np.mean(perEoi400[:-1]))
print(np.mean(meanE280[:-1]))
print(np.mean(meanEoi400[:-1]))
print(np.mean(maxE280[:-1]))
print(np.mean(maxEoi400[:-1]))
# Out:
# <xarray.DataArray 'corr' ()>
# array(16.44412593)
# <xarray.DataArray 'corr' ()>
# array(29.33515365)
# <xarray.DataArray 'corr' ()>
# array(0.32186309)
# <xarray.DataArray 'corr' ()>
# array(0.36408728)
# <xarray.DataArray 'corr' ()>
# array(0.48031062)
# <xarray.DataArray 'corr' ()>
# array(0.56576029)

# %% [markdown]
# ## Figure S02: MMM and std of correlation maps

# %%
#These masks have been saved from Fig05Fig06FigS09.ipynb
maskE = xr.open_dataset(folder+'1x1oceanmaskE280.nc')
maskEoi = xr.open_dataset(folder+'1x1oceanmaskEoi400.nc')

# %%
#Arrays that count how many models show the same + or - sign for E280
mmmE280 = dsE280.corr[:-1].mean(dim='model').where(maskE.sss>-1) #Excluding HadGEM3

count_pos = mmmE280.where(dsE280.corr[:-1]>0).count(dim='model')
count_neg = mmmE280.where(dsE280.corr[:-1]<0).count(dim='model')

#Construct 2D arrays of longitude and latitude to produce scatter plots for significance (>= 12 models agree on sign)
lon = mmmE280.lon
lat = mmmE280.lat

coords = xr.Dataset(data_vars = dict(lat2D=(["lat", "lon"], np.repeat(lat.values[:, np.newaxis], len(lon), axis=1))), coords = dict(lat = lat.values, lon = lon.values))
coords['lon2D'] = coords.lat2D.copy(deep=True)
coords.lon2D[:] = np.transpose(np.repeat(lon.values[:, np.newaxis], len(lat), axis=1))

threshold = 12
mask_pos = count_pos.where(count_pos>=threshold)
mask_neg = count_neg.where(count_neg>=threshold)

#Arrays that count how many models show the same + or - sign for E280
mmmEoi400 = dsEoi400.corr[:-1].mean(dim='model').where(maskEoi.sss>-1) #Excluding HadGEM3

count_pos = mmmEoi400.where(dsEoi400.corr[:-1]>0).count(dim='model')
count_neg = mmmEoi400.where(dsEoi400.corr[:-1]<0).count(dim='model')

#Construct 2D arrays of longitude and latitude to produce scatter plots for significance (>= 12 models agree on sign)
lon = mmmEoi400.lon
lat = mmmEoi400.lat

coords = xr.Dataset(data_vars = dict(lat2D=(["lat", "lon"], np.repeat(lat.values[:, np.newaxis], len(lon), axis=1))), coords = dict(lat = lat.values, lon = lon.values))
coords['lon2D'] = coords.lat2D.copy(deep=True)
coords.lon2D[:] = np.transpose(np.repeat(lon.values[:, np.newaxis], len(lat), axis=1))

mask_pos1 = count_pos.where(count_pos>=threshold)
mask_neg1 = count_neg.where(count_neg>=threshold)

# %%
cmap1 = plt.get_cmap('cmo.thermal')
cmap1.set_under('black')

cmap2 = plt.get_cmap('cmo.balance')
cmap2.set_under('black')

maskE = xr.open_dataset(folder+'1x1oceanmaskE280.nc')
maskEoi = xr.open_dataset(folder+'1x1oceanmaskEoi400.nc')

plt.rcParams['xtick.labelsize']=13
plt.rcParams['ytick.labelsize']=13
plt.rcParams['axes.labelsize'] = 13

fig = plt.figure(figsize=(15,15),dpi=300)
spec = fig.add_gridspec(2, 2)

ax0 = fig.add_subplot(spec[0, 0:1], projection=ccrs.Miller())

im = ax0.pcolormesh(dsE280.lon, dsE280.lat, dsE280.corr[:-1].mean(dim='model').where(maskE.sss>-1).fillna(-1000), transform = ccrs.PlateCarree(), cmap=cmap2, shading='auto',vmin = -0.5, vmax = 0.5)
cp1 = ax0.contour(dsE280.lon, dsE280.lat, dsE280.corr[:-1].where(maskE.sss>-1).mean(dim='model'), levels=[0.2, 1e24], colors='w', zorder =1, alpha=0.8,transform = ccrs.PlateCarree())

cs1 = ax0.scatter(coords.lon2D.where(mask_pos>0)[::2,::2], coords.lat2D.where(mask_pos>0)[::2,::2], s=10, facecolors='none', edgecolors='black', linewidth=0.5)
cs2 = ax0.scatter(coords.lon2D.where(mask_neg>0)[::2,::2], coords.lat2D.where(mask_neg>0)[::2,::2], s=10, facecolors='none', edgecolors='black', linewidth=0.5)

ax0.set_title(r'(a)', fontsize=13,loc='left')
ax0.set_title(r'PI', fontsize=13,loc='right')
fig.colorbar(im, ax = ax0, location = 'bottom', label='Correlation (R)', fraction = 0.1, shrink=0.8, pad=0.08)
ax0.clabel(cp1, inline=True, inline_spacing=70, fmt = '%.1f',  fontsize=11)

ax1 = fig.add_subplot(spec[1, 0:1], projection=ccrs.Miller())

im = ax1.pcolormesh(dsE280.lon, dsE280.lat, dsE280.corr[:-1].std(dim='model').where(maskE.sss>-1).fillna(-1000), transform = ccrs.PlateCarree(), cmap=cmap1, shading='auto',vmin = 0, vmax = 0.3)
cp1 = ax1.contour(dsE280.lon, dsE280.lat, dsE280.corr[:-1].where(maskE.sss>-1).std(dim='model'), levels=[0.2, 1e24], colors='w', zorder =1, alpha=0.8,transform = ccrs.PlateCarree())
ax1.set_title(r'(c)', fontsize=13,loc='left')
ax1.set_title(r'PI', fontsize=13,loc='right')
fig.colorbar(im, ax = ax1, location = 'bottom', label='Standard deviation', fraction = 0.1, shrink=0.8, pad=0.08)
ax1.clabel(cp1, inline=True, inline_spacing=0.1, fmt = '%.1f',  fontsize=11)

ax2 = fig.add_subplot(spec[0, 1:], projection=ccrs.Miller())

im = ax2.pcolormesh(dsEoi400.lon, dsEoi400.lat, dsEoi400.corr[:-1].mean(dim='model').where(maskEoi.sss>-1).fillna(-1000), transform = ccrs.PlateCarree(), cmap=cmap2, shading='auto',vmin = -0.5, vmax = 0.5)
cp1 = ax2.contour(dsEoi400.lon, dsEoi400.lat, dsEoi400.corr[:-1].mean(dim='model').where(maskEoi.sss>-1), levels=[0.2, 1e24], colors='w', zorder =1, alpha=0.8,transform = ccrs.PlateCarree())
ax2.set_title(r'(b)', fontsize=13,loc='left')
ax2.set_title(r'mPWP', fontsize=13,loc='right')
fig.colorbar(im, ax = ax2, location = 'bottom', label='Correlation (R)', fraction = 0.1, shrink=0.8, pad=0.08)
ax2.clabel(cp1, inline=True, inline_spacing=70, fmt = '%.1f',  fontsize=11)

cs1 = ax2.scatter(coords.lon2D.where(mask_pos1>0)[::2,::2], coords.lat2D.where(mask_pos1>0)[::2,::2], s=10, facecolors='none', edgecolors='black', linewidth=0.5)
cs2 = ax2.scatter(coords.lon2D.where(mask_neg1>0)[::2,::2], coords.lat2D.where(mask_neg1>0)[::2,::2], s=10, facecolors='none', edgecolors='black', linewidth=0.5)

ax3 = fig.add_subplot(spec[1, 1:], projection=ccrs.Miller())

im = ax3.pcolormesh(dsEoi400.lon, dsEoi400.lat, dsEoi400.corr[:-1].std(dim='model').where(maskEoi.sss>-1).fillna(-1000), transform = ccrs.PlateCarree(), cmap=cmap1, shading='auto',vmin = 0, vmax = 0.3)
cp1 = ax3.contour(dsEoi400.lon, dsEoi400.lat, dsEoi400.corr[:-1].std(dim='model').where(maskEoi.sss>-1), levels=[0.2, 1e24], colors='w', zorder =1, alpha=0.8,transform = ccrs.PlateCarree())
ax3.set_title(r'(d)', fontsize=13,loc='left')
ax3.set_title(r'mPWP', fontsize=13,loc='right')
fig.colorbar(im, ax = ax3, location = 'bottom', label='Standard deviation', fraction = 0.1, shrink=0.8, pad=0.08)
ax3.clabel(cp1, inline=True, inline_spacing=0.1, fmt = '%.1f',  fontsize=11)

for ax in [ax0,ax1,ax2,ax3]:
    ax.set_extent([-90, 30, 20, 85], ccrs.PlateCarree())
    # Longitude labels
    ax.set_xticks(np.arange(-90,31,30), crs=ccrs.PlateCarree())
    lon_formatter = cticker.LongitudeFormatter()
    ax.xaxis.set_major_formatter(lon_formatter)

    # Latitude labels
    ax.set_yticks(np.arange(30,80,15), crs=ccrs.PlateCarree())
    lat_formatter = cticker.LatitudeFormatter()
    ax.yaxis.set_major_formatter(lat_formatter)

fig.tight_layout()
plt.savefig('figs02.png', bbox_inches='tight')
# Out:
# /var/folders/f4/c_hqzq2n50q925l69wbn3_dw0000gn/T/ipykernel_95692/4099217143.py:2: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("cmo.thermal").copy()
#   cmap1.set_under('black')
# /var/folders/f4/c_hqzq2n50q925l69wbn3_dw0000gn/T/ipykernel_95692/4099217143.py:5: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. This has been deprecated since 3.3 and in 3.6, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = mpl.cm.get_cmap("cmo.balance").copy()
#   cmap2.set_under('black')
# ...
